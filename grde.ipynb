# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayesha-Siddiqa-khan/Python-Alpha/blob/main/grde.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
marks = int(input("enter student marks : "))

if(marks >= 90):
    grade = "A"



elif(marks >= 80 and marks < 90 ):
    grade = "B"

elif(marks >= 70 and marks < 80):
    grade = "c"

else:
    grade = "D"


print("grade of student ->",grade)
# Out:
# enter student marks : 89
# grade of student -> B

# %%
num = int(input("the number is: "))
rem = num % 2

if(rem == 0):
    print("this number is even")
else:
    print("this number is odd")
# Out:
# the number is: 45
# this number is odd

# %%
a = int(input("enter first number: "))
b = int(input("enter second number: "))
c = int(input("enter third number: "))

if(a >= b and a >= c):
    print("first number is greater =", a)

elif(b >= c and b>=a ):
    print("second number is greater =", b)

else:
      print("third is largest =", c)
# Out:
# enter first number: 45
# enter second number: 3
# enter third number: 2
# first number is greater = 45
